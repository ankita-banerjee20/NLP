# %%
import nltk
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

#downloading all neccessary packages related to nltk
nltk.download('all')

import spacy
nlp = spacy.load("en_core_web_sm")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package alpino to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\book_grammars.zip.
# [nltk_data]    | Downloading package brown to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown.zip.
# [nltk_data]    | Downloading package brown_tei to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\chat80.zip.
# [nltk_data]    | Downloading package city_database to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\city_database.zip.
# [nltk_data]    | Downloading package cmudict to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package conll2000 to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package crubadan to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package floresta to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gazetteers.zip.
# [nltk_data]    | Downloading package genesis to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\genesis.zip.
# [nltk_data]    | Downloading package gutenberg to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gutenberg.zip.
# [nltk_data]    | Downloading package ieer to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ieer.zip.
# [nltk_data]    | Downloading package inaugural to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\inaugural.zip.
# [nltk_data]    | Downloading package indian to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\indian.zip.
# [nltk_data]    | Downloading package jeita to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package kimmo to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\kimmo.zip.
# [nltk_data]    | Downloading package knbc to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package large_grammars to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\mac_morpho.zip.
# [nltk_data]    | Downloading package machado to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package masc_tagged to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping misc\mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\nps_chat.zip.
# [nltk_data]    | Downloading package omw to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package paradigms to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\paradigms.zip.
# [nltk_data]    | Downloading package pe08 to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pe08.zip.
# [nltk_data]    | Downloading package perluniprops to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping misc\perluniprops.zip.
# [nltk_data]    | Downloading package pil to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pil.zip.
# [nltk_data]    | Downloading package pl196x to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pl196x.zip.
# [nltk_data]    | Downloading package porter_test to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping stemmers\porter_test.zip.
# [nltk_data]    | Downloading package ppattach to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package pros_cons to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pros_cons.zip.
# [nltk_data]    | Downloading package ptb to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ptb.zip.
# [nltk_data]    | Downloading package punkt to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping tokenizers\punkt.zip.
# [nltk_data]    | Downloading package qc to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\qc.zip.
# [nltk_data]    | Downloading package reuters to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package rslp to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping stemmers\rslp.zip.
# [nltk_data]    | Downloading package rte to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package senseval to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\smultron.zip.
# [nltk_data]    | Downloading package snowball_data to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\state_union.zip.
# [nltk_data]    | Downloading package stopwords to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\swadesh.zip.
# [nltk_data]    | Downloading package switchboard to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\switchboard.zip.
# [nltk_data]    | Downloading package tagsets to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping help\tagsets.zip.
# [nltk_data]    | Downloading package timit to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\timit.zip.
# [nltk_data]    | Downloading package toolbox to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\toolbox.zip.
# [nltk_data]    | Downloading package treebank to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr.zip.
# [nltk_data]    | Downloading package udhr2 to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package verbnet to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\verbnet3.zip.
# [nltk_data]    | Downloading package webtext to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet_ic.zip.
# [nltk_data]    | Downloading package words to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\words.zip.
# [nltk_data]    | Downloading package ycoe to C:\Users\Ankita
# [nltk_data]    |     Banerjee\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all

# %% [markdown]
# #### Exercise1:
# - Convert these list of words into base form using Stemming and Lemmatization and observe the transformations
# - Write a short note on the words that have different base words using stemming and Lemmatization

# %%
lst_words = ['running', 'painting', 'walking', 'dressing', 'likely', 'children', 'whom', 'good', 'ate', 'fishing']

# %%
for word in lst_words:
    print(word, "|", stemmer.stem(word))
# Out:
# running | run
# painting | paint
# walking | walk
# dressing | dress
# likely | like
# children | children
# whom | whom
# good | good
# ate | ate
# fishing | fish

# %%
doc = nlp("running painting walking dressing likely children who good ate fishing")

# %%
for token in doc:
    print(token, "|", token.lemma_)
# Out:
# running | run
# painting | paint
# walking | walk
# dressing | dress
# likely | likely
# children | child
# who | who
# good | good
# ate | eat
# fishing | fishing

# %% [markdown]
# #### Exercise2:
# - convert the given text into it's base form using both stemming and lemmatization

# %%
text = """Latha is very multi talented girl.She is good at many skills like dancing, running, singing, playing.She also likes eating Pav Bhagi. she has a 
habit of fishing and swimming too.Besides all this, she is a wonderful at cooking too.
"""

# %%
#using lemmatisation in spacy
new_doc = nlp(text)

# %%
base_word = []
for token in new_doc:
    base_word.append(token.lemma_)

# %%
" ".join(base_word)
# Out:
# 'Latha be very multi talented girl . she be good at many skill like dancing , running , singing , play . she also like eat Pav Bhagi . she have a \n habit of fishing and swim too . besides all this , she be a wonderful at cook too . \n'

# %%
#using stemming in nltk
tokens = nltk.word_tokenize(text)
base_word = []
for token in tokens:
    base_word.append(stemmer.stem(token))

# %%
" ".join(base_word)
# Out:
# 'latha is veri multi talent girl.sh is good at mani skill like danc , run , sing , playing.sh also like eat pav bhagi . she ha a habit of fish and swim too.besid all thi , she is a wonder at cook too .'
